# %%
import pandas as pd
df = pd.read_csv("./hackathon_song_normalize.csv")

# %%
df = df.drop_duplicates(subset=["artist","name"])

# %%
df
# Out:
#               artist  ID Artist                                    name
# 0     Britney Spears        147                  Oops!...I Did It Again  \
# 1          blink 182        120                    All The Small Things
# 2         Faith Hill        307                                 Breathe
# 3           Bon Jovi        137                            It's My Life
# 4              NSYNC        680                             Bye Bye Bye
# ...              ...        ...                                     ...
# 1994  Jonas Brothers        458                                  Sucker
# 1995    Taylor Swift        875                            Cruel Summer
# 1996    Blanco Brown        118                              The Git Up
# 1997       Sam Smith        791  Dancing With A Stranger (with Normani)
# 1998     Post Malone        733                                 Circles
#
#       duration_ms  explicit  year  popularity  danceability  energy  key
# 0          211160     False  2000          77         0.751   0.834    1  \
# 1          167066     False  1999          79         0.434   0.897    0
# 2          250546     False  1999          66         0.529   0.496    7
# 3          224493     False  2000          78         0.551   0.913    0
# 4          200560     False  2000          65         0.614   0.928    8
# ...           ...       ...   ...         ...           ...     ...  ...
# 1994       181026     False  2019          79         0.842   0.734    1
# 1995       178426     False  2019          78         0.552   0.702    9
# 1996       200593     False  2019          69         0.847   0.678    9
# 1997       171029     False  2019          75         0.741   0.520    8
# 1998       215280     False  2019          85         0.695   0.762    0
#
#       loudness  mode  speechiness  acousticness  instrumentalness  liveness
# 0       -5.444     0       0.0437        0.3000          0.000018    0.3550  \
# 1       -4.918     1       0.0488        0.0103          0.000000    0.6120
# 2       -9.007     1       0.0290        0.1730          0.000000    0.2510
# 3       -4.063     0       0.0466        0.0263          0.000013    0.3470
# 4       -4.806     0       0.0516        0.0408          0.001040    0.0845
# ...        ...   ...          ...           ...               ...       ...
# 1994    -5.065     0       0.0588        0.0427          0.000000    0.1060
# 1995    -5.707     1       0.1570        0.1170          0.000021    0.1050
# 1996    -8.635     1       0.1090        0.0669          0.000000    0.2740
# 1997    -7.513     1       0.0656        0.4500          0.000002    0.2220
# 1998    -3.497     1       0.0395        0.1920          0.002440    0.0863
#
#       valence    tempo             genre  Column1
# 0       0.894   95.053               pop      NaN
# 1       0.684  148.726         rock, pop      NaN
# 2       0.278  136.859      pop, country      NaN
# 3       0.544  119.992       rock, metal      NaN
# 4       0.879  172.656               pop      NaN
# ...       ...      ...               ...      ...
# 1994    0.952  137.958               pop      NaN
# 1995    0.564  169.994               pop      NaN
# 1996    0.811   97.984  hip hop, country      NaN
# 1997    0.347  102.998               pop      NaN
# 1998    0.553  120.042           hip hop      NaN
#
# [1925 rows x 20 columns]

# %%
import pandas as pd

# Assuming df is your DataFrame
average_df = df[['artist','duration_ms','popularity',"danceability","energy","loudness","speechiness","acousticness","instrumentalness","liveness","valence","tempo"]].groupby('artist').mean()
average_df.reset_index(level=0, inplace=True)

# %%
import pandas as pd

# Assuming df is your DataFrame
aggregate_df = df.groupby('artist').agg({
    'duration_ms': 'mean',
    'explicit': 'mean',
    'popularity': 'mean',
    'danceability': 'mean',
    'energy': 'mean',
    'loudness': 'mean',
    'speechiness': 'mean',
    'acousticness': 'mean',
    'instrumentalness': 'mean',
    'liveness': 'mean',
    'tempo': 'mean',
    'valence': 'mean',
    'year': ['min', 'max'],
    'name': 'size'
})

# # Flatten the multi-level column names
def agg_col(col):
    if col[0] == 'year':
        return '_'.join(col).strip()
    else:
        return col[0]
aggregate_df.columns = [agg_col(col) for col in aggregate_df.columns.values]

# # If you want to keep 'artist' as a column and not an index
aggregate_df.reset_index(level=0, inplace=True)

# %%
aggregate_df.to_csv("hackathon_song_normalize_artist_grouped.csv")

# %%
import pandas as pd
# First, you split the strings into lists
df['genre'] = df['genre'].str.split(',')

# Then you can explode the lists into separate rows
df = df.explode('genre')
df['genre'] = df['genre'].apply(lambda x : x.lower().replace(" ",""))
# Assuming df is your DataFrame
aggregate_df = df.groupby('genre').agg({
    'duration_ms': 'mean',
    'explicit': 'mean',
    'popularity': 'mean',
    'danceability': 'mean',
    'energy': 'mean',
    'loudness': 'mean',
    'speechiness': 'mean',
    'acousticness': 'mean',
    'instrumentalness': 'mean',
    'liveness': 'mean',
    'tempo': 'mean',
    'valence': 'mean',
    'year': ['min', 'max'],
    'name': 'size'
})

# # Flatten the multi-level column names
def agg_col(col):
    if col[0] == 'year':
        return '_'.join(col).strip()
    else:
        return col[0]
aggregate_df.columns = [agg_col(col) for col in aggregate_df.columns.values]

# # If you want to keep 'artist' as a column and not an index
aggregate_df.reset_index(level=0, inplace=True)

# %%
aggregate_df.to_csv("hackathon_song_normalize_genre_grouped.csv")

# %%
aggregate_df
# Out:
#                 genre    duration_ms  explicit  popularity  danceability
# 0               blues  244643.250000  0.000000   45.500000      0.649750  \
# 1           classical  219560.000000  0.000000   63.000000      0.590000
# 2             country  222198.700000  0.050000   56.200000      0.576750
# 3    dance/electronic  216096.440318  0.116711   54.840849      0.668103
# 4       easylistening  234931.000000  0.000000   61.428571      0.612000
# 5       folk/acoustic  220183.650000  0.050000   60.200000      0.567400
# 6              hiphop  233824.904826  0.549598   61.864611      0.717889
# 7                jazz  224813.000000  0.000000   57.500000      0.548000
# 8               latin  227494.682540  0.095238   58.952381      0.725063
# 9               metal  234249.218750  0.140625   67.671875      0.508281
# 10                pop  228585.356094  0.252074   59.063178      0.670913
# 11                r&b  239777.981524  0.284065   58.632794      0.690370
# 12               rock  227571.444444  0.088889   62.626667      0.555938
# 13              set()  214065.409091  0.090909   57.454545      0.739000
# 14  world/traditional  219063.800000  0.100000   53.800000      0.603000
#
#       energy   loudness  speechiness  acousticness  instrumentalness
# 0   0.669750  -5.616500     0.091900      0.021052          0.112260  \
# 1   0.578000  -5.798000     0.052800      0.612000          0.000162
# 2   0.729650  -5.517100     0.060755      0.213051          0.000014
# 3   0.769804  -5.129464     0.078444      0.106700          0.038686
# 4   0.689714  -7.598714     0.051457      0.240632          0.038343
# 5   0.728550  -6.353800     0.042185      0.197199          0.043269
# 6   0.699572  -5.607038     0.151992      0.116994          0.006212
# 7   0.233000 -14.418000     0.031700      0.686000          0.004443
# 8   0.789016  -4.685508     0.095095      0.151821          0.000660
# 9   0.831172  -4.854938     0.047275      0.040575          0.005203
# 10  0.716323  -5.515188     0.100836      0.132111          0.011676
# 11  0.662139  -5.930640     0.114789      0.151763          0.006726
# 12  0.790596  -5.151111     0.059479      0.073963          0.030360
# 13  0.738955  -5.863273     0.064864      0.181177          0.036020
# 14  0.685700  -6.187800     0.079530      0.272961          0.198378
#
#     year_min  year_max  name
# 0       1999      2007     4
# 1       2015      2015     1
# 2       1999      2019    20
# 3       1999      2019   377
# 4       1999      2017     7
# 5       1999      2017    20
# 6       1998      2020   746
# 7       2003      2005     2
# 8       1999      2019    63
# 9       1999      2019    64
# 10      1998      2020  1567
# 11      1998      2019   433
# 12      1999      2019   225
# 13      1999      2019    22
# 14      2000      2020    10

# %%
aggregate_df.drop_duplicates(subset=['artist'])
# Out:
#            artist  duration_ms  explicit  popularity  danceability  energy
# 0             112     229013.0       0.0        60.0        0.6685  0.6150  \
# 1        2 Chainz     219053.0       0.5        70.0        0.6925  0.7020
# 2       21 Savage     254465.0       1.0        76.0        0.8605  0.4915
# 3            2Pac     252279.5       1.0        62.5        0.7755  0.6600
# 4    3 Doors Down     243602.4       0.0        65.4        0.5278  0.7926
# ..            ...          ...       ...         ...           ...     ...
# 830   girl in red     184153.0       0.0        82.0        0.5660  0.3660
# 831     iann dior     133890.5       0.5        70.5        0.6535  0.6720
# 832           iio     253586.0       0.0        54.0        0.6610  0.8550
# 833      t.A.T.u.     214440.0       1.0        39.0        0.5270  0.8340
# 834     will.i.am     292453.0       0.5        63.5        0.7230  0.6595
#
#      loudness  speechiness  acousticness  instrumentalness  year_min  year_max
# 0     -5.3980     0.187450      0.006685          0.000004      2001      2001
# 1     -5.9830     0.275000      0.042850          0.000443      2013      2017
# 2     -7.9350     0.218000      0.027250          0.000975      2017      2018
# 3     -6.0085     0.124850      0.061550          0.000000      2001      2004
# 4     -5.5716     0.036220      0.015864          0.000003      2000      2012
# ..        ...          ...           ...               ...       ...       ...
# 830  -12.8080     0.028000      0.113000          0.181000      2018      2018
# 831   -5.9240     0.034100      0.087550          0.000000      2019      2019
# 832   -8.4030     0.037700      0.072200          0.018500      2006      2006
# 833   -5.7670     0.047400      0.041100          0.005990      2020      2020
# 834   -6.2960     0.061425      0.015013          0.031792      2007      2013
#
# [835 rows x 12 columns]

# %%
# First, you split the strings into lists
df['genre'] = df['genre'].str.split(',')

# Then you can explode the lists into separate rows
df = df.explode('genre')
df['genre'] = df['genre'].apply(lambda x : x.lower().replace(" ",""))
df['duration'] = df['duration_ms']/1000

# %%
c = df[["artist", "name", "year","duration", "explicit","popularity"]]

# %%
c
# Out:
#               artist                                    name  year  duration
# 0     Britney Spears                  Oops!...I Did It Again  2000   211.160  \
# 1          blink 182                    All The Small Things  1999   167.066
# 1          blink 182                    All The Small Things  1999   167.066
# 2         Faith Hill                                 Breathe  1999   250.546
# 2         Faith Hill                                 Breathe  1999   250.546
# ...              ...                                     ...   ...       ...
# 1995    Taylor Swift                            Cruel Summer  2019   178.426
# 1996    Blanco Brown                              The Git Up  2019   200.593
# 1996    Blanco Brown                              The Git Up  2019   200.593
# 1997       Sam Smith  Dancing With A Stranger (with Normani)  2019   171.029
# 1998     Post Malone                                 Circles  2019   215.280
#
#       explicit  popularity
# 0        False          77
# 1        False          79
# 1        False          79
# 2        False          66
# 2        False          66
# ...        ...         ...
# 1995     False          78
# 1996     False          69
# 1996     False          69
# 1997     False          75
# 1998     False          85
#
# [3703 rows x 6 columns]

# %%
df[[ "year", "genre", "duration", "popularity"]].to_csv("songs_genre_exploded.csv")
